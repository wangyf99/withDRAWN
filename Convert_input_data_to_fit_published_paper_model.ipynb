# %%
import pandas as pd

# %%
train1 = pd.read_csv("train1.csv")
test1 = pd.read_csv("test1.csv")
val = pd.read_csv("val.csv")

# %%
drug_labels_smiles_final = pd.read_csv("tox_labels_smiles_final.csv")
drug_labels_smiles_final
# Out:
#       Unnamed: 0                                               drug  \
# 0              0                                          chembl479
# 1              1                                        chembl12713
# 2              2                                          chembl583
# 3              3                                        chembl17157
# 4              4                                          chembl121
# ...          ...                                                ...
# 1290        1084                                       tirbanibulin
# 1291        1085                                      naproxen oral
# 1292        1086                                     fingolimod hcl
# 1293        1087                                pyrazinamide tablet
# 1294        1088  abacavir sulfate- dolutegravir sodium- lamivudine
#
#       withdrawn  withdrawn_cards  withdrawn_liver  withdrawn_neuro  ATC_cards  \
# ...

# %%
drug_labels_smiles_final = drug_labels_smiles_final.loc[:, ['drug', 'withdrawn', 'smiles']]

# %%
drug_labels_smiles_final.columns = ['drug', 'withdrawn_class', 'smiles']

# %%
drug_labels_smiles_final
# Out:
#                                                    drug  withdrawn_class  \
# 0                                             chembl479                1
# 1                                           chembl12713                1
# 2                                             chembl583                1
# 3                                           chembl17157                1
# 4                                             chembl121                1
# ...                                                 ...              ...
# 1290                                       tirbanibulin                0
# 1291                                      naproxen oral                0
# 1292                                     fingolimod hcl                0
# 1293                                pyrazinamide tablet                0
# 1294  abacavir sulfate- dolutegravir sodium- lamivudine                0
#
#                                                  smiles
# ...

# %%
train1.columns = ['drug']

# %%
merged_train = train1.merge(drug_labels_smiles_final, on='drug', how='inner')

# %%
test1.columns = ['drug']
merged_test = test1.merge(drug_labels_smiles_final, on='drug')
merged_test
# Out:
#                                   drug  withdrawn_class  \
# 0                        chembl2105233                1
# 1                         chembl146095                1
# 2                        chembl2106829                1
# 3                         chembl282724                1
# 4                         chembl462547                1
# 5                        chembl1213351                1
# 6                          chembl53292                1
# 7                        chembl1256841                1
# 8                           chembl1291                1
# 9                        chembl1200695                1
# 10                         chembl21869                1
# 11                       chembl3187246                1
# 12                           chembl646                1
# 13                         chembl37744                1
# 14                       chembl3188576                1
# 15                         chembl13376                1
# ...

# %%
val.columns = ['drug']
merged_val = val.merge(drug_labels_smiles_final, on='drug')
merged_val
# Out:
#                            drug  withdrawn_class  \
# 0                  chembl395110                1
# 1                  chembl311498                1
# 2                   chembl16080                1
# 3                     chembl111                1
# 4                   chembl24072                1
# 5                 chembl2104793                1
# 6                 chembl1998966                1
# 7                     chembl448                1
# 8                     chembl447                1
# 9                 chembl1201201                1
# 10                   chembl1729                1
# 11                chembl1204165                1
# 12                chembl2107253                1
# 13                chembl3142541                1
# 14                  chembl70046                1
# 15                chembl3989830                1
# 16                 chembl404108                1
# 17                chembl1516474                1
# ...

# %%
merged_train.to_csv("merged_train.csv")
merged_test.to_csv("merged_test.csv")
merged_val.to_csv("merged_val.csv")

# %% [markdown]
# ### New Merged dataset creation for imbalanced dataset from the seed_0 as an example

# %%
train = pd.read_csv("/Users/alexwang/Documents/GitHub/withDRAWN/data/WithDrawn/seed_0/merged_train.csv")
test = pd.read_csv("/Users/alexwang/Documents/GitHub/withDRAWN/data/WithDrawn/seed_0/merged_test.csv")
val = pd.read_csv("/Users/alexwang/Documents/GitHub/withDRAWN/data/WithDrawn/seed_0/merged_val.csv")

# %%
drug_labels_smiles_final = pd.read_csv("tox_labels_smiles_final.csv")
drug_labels_smiles_final
# Out:
#       Unnamed: 0                                               drug  \
# 0              0                                          chembl479
# 1              1                                        chembl12713
# 2              2                                          chembl583
# 3              3                                        chembl17157
# 4              4                                          chembl121
# ...          ...                                                ...
# 1290        1084                                       tirbanibulin
# 1291        1085                                      naproxen oral
# 1292        1086                                     fingolimod hcl
# 1293        1087                                pyrazinamide tablet
# 1294        1088  abacavir sulfate- dolutegravir sodium- lamivudine
#
#       withdrawn  withdrawn_cards  withdrawn_liver  withdrawn_neuro  ATC_cards  \
# ...

# %%
drug_labels_smiles_final = drug_labels_smiles_final.loc[:, ['drug', 'withdrawn', 'smiles']]

# %%
drug_labels_smiles_final.columns = ['drug', 'withdrawn_class', 'smiles']

# %%
drug_labels_smiles_final
# Out:
#                                                    drug  withdrawn_class  \
# 0                                             chembl479                1
# 1                                           chembl12713                1
# 2                                             chembl583                1
# 3                                           chembl17157                1
# 4                                             chembl121                1
# ...                                                 ...              ...
# 1290                                       tirbanibulin                0
# 1291                                      naproxen oral                0
# 1292                                     fingolimod hcl                0
# 1293                                pyrazinamide tablet                0
# 1294  abacavir sulfate- dolutegravir sodium- lamivudine                0
#
#                                                  smiles
# ...

# %%
train
# Out:
#                                                  smiles  withdrawn_class
# 0                 CSc1ccc2c(c1)N(CCC1CCCCN1C)c1ccccc1S2                1
# 1     O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...                1
# 2      Cc1c(F)c(N2CCNC(C)C2)cc2c1c(=O)c(C(=O)O)cn2C1CC1                1
# 3     CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...                1
# 4               CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1                1
# ...                                                 ...              ...
# 1030   O=C(Cc1ccc(-c2ccc(OCCN3CCOCC3)cc2)cn1)NCc1ccccc1                0
# 1031                   COc1ccc2cc([C@H](C)C(=O)O)ccc2c1                0
# 1032                  CCCCCCCCc1ccc(CCC(N)(CO)CO)cc1.Cl                0
# 1033                                     NC(=O)c1cnccn1                0
# 1034  Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1....                0
#
# [1035 rows x 2 columns]

# %%
drug_labels_smiles_final
# Out:
#                                                    drug  withdrawn_class  \
# 0                                             chembl479                1
# 1                                           chembl12713                1
# 2                                             chembl583                1
# 3                                           chembl17157                1
# 4                                             chembl121                1
# ...                                                 ...              ...
# 1290                                       tirbanibulin                0
# 1291                                      naproxen oral                0
# 1292                                     fingolimod hcl                0
# 1293                                pyrazinamide tablet                0
# 1294  abacavir sulfate- dolutegravir sodium- lamivudine                0
#
#                                                  smiles
# ...

# %%
train_smiles = train.merge(drug_labels_smiles_final, on = ['smiles', 'withdrawn_class'], how = 'inner')

# %%
train_smiles.drop_duplicates()[['drug', 'withdrawn_class', 'smiles']].to_csv("merged_train.csv")

# %%
val_smiles = val.merge(drug_labels_smiles_final, on = ['smiles', 'withdrawn_class'], how = 'inner')

# %%
val_smiles.drop_duplicates()[['drug', 'withdrawn_class', 'smiles']].to_csv("merged_val.csv")

# %%
test_smiles = val.merge(drug_labels_smiles_final, on = ['smiles', 'withdrawn_class'], how = 'inner')

# %%
test_smiles.drop_duplicates()[['drug', 'withdrawn_class', 'smiles']].to_csv("merged_test.csv")
